# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import pandas as pd

# %%
# !gdown --id 1T5dB-Q7qAJTl-CLoYdruzKSdO89ZezMy
# Out:
# /usr/local/lib/python3.10/dist-packages/gdown/cli.py:121: FutureWarning: Option `--id` was deprecated in version 4.3.1 and will be removed in 5.0. You don't need to pass it anymore to use a file ID.
#   warnings.warn(
# Downloading...
# From: https://drive.google.com/uc?id=1T5dB-Q7qAJTl-CLoYdruzKSdO89ZezMy
# To: /content/Titanic-Dataset.csv
# 100% 61.2k/61.2k [00:00<00:00, 61.3MB/s]

# %%
pd.read_csv ('/content/Titanic-Dataset.csv')
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
#4.определяем количесто пустых ячеек в каждом столбце датасета
df=pd.read_csv ('/content/Titanic-Dataset.csv')
df.isnull().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %%
#5.Заполняем пустые ячейки используя замещение данных средним значением.
df[['Age', 'Cabin', 'Embarked']] = df[['Age', 'Cabin', 'Embarked']].fillna(df[['Age', 'Cabin', 'Embarked']].mean ())
df
# Out:
# <ipython-input-6-3d9ffc9ec3a1>:2: FutureWarning: The default value of numeric_only in DataFrame.mean is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   df[['Age', 'Cabin', 'Embarked']] = df[['Age', 'Cabin', 'Embarked']].fillna(df[['Age', 'Cabin', 'Embarked']].mean ())
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex        Age  \
# ...

# %%
#7.1 количество уникальных значение (p.s.: пункт 6 пропускаем при выполнении пункта 5)
df.nunique ()
# Out:
# PassengerId    891
# Survived         2
# Pclass           3
# Name           891
# Sex              2
# Age             89
# SibSp            7
# Parch            7
# Ticket         681
# Fare           248
# Cabin          147
# Embarked         3
# dtype: int64

# %%
#7.2 минимальное и максимальное значение
df.min()
# Out:
# <ipython-input-8-aa2d2f713da1>:2: FutureWarning: The default value of numeric_only in DataFrame.min is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   df.min()
# PassengerId                      1
# Survived                         0
# Pclass                           1
# Name           Abbing, Mr. Anthony
# Sex                         female
# Age                           0.42
# SibSp                            0
# Parch                            0
# Ticket                      110152
# Fare                           0.0
# dtype: object

# %%
 df.max()
# Out:
# <ipython-input-9-4c1ddf8920ff>:1: FutureWarning: The default value of numeric_only in DataFrame.max is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   df.max()
# PassengerId                            891
# Survived                                 1
# Pclass                                   3
# Name           van Melkebeke, Mr. Philemon
# Sex                                   male
# Age                                   80.0
# SibSp                                    8
# Parch                                    6
# Ticket                           WE/P 5735
# Fare                              512.3292
# dtype: object

# %%
# 8.определить влияние всех признаков на признак Survived(выживание).
from sklearn.ensemble import RandomForestRegressor
from sklearn.model_selection import train_test_split
from sklearn.feature_selection import RFECV
import matplotlib.pyplot as plt

# %%
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size = 0.1, random_state=891)
rf = RandomForestRegressor (random_state=0)
rf.fit(x_train, y_train)
# Out:
# RandomForestRegressor(random_state=0)

# %%
f_i = list(zip(df_num.columns, rf.feature_importances_))
f_i.sort(key = lambda x: x[1])
plt.barh([x[0] for x in f_i], [x[1] for x in f_i])
# Out:
# <BarContainer object of 8 artists>

# %%
#Выводы:
#Pclass положительно влияет на выживание Чем выше класс круиза, тем более обеспеченные пассажиры. Возможно их статус или денежное обеспечение увеличило шанс выжить.
#Age положительно влияет на выживание. Взрослому человеку спастись легче, чем ребенку.
#SibSp и Parch отрицательно влияют на выживание. Одному спастись проще, чем семье.
#Sex отрицательно влияют на выживание. Мужчинам спастись было сложнее, чем женщинам.Сначала спасали женщин и детей.

# %%
df_num=df.copy()

# %%
df_num.loc[:, 'Sex'] = df_num['Sex'].astype('category').cat.codes
df_num.loc[:, 'Embarked'] = df_num['Embarked'].astype('category').cat.codes
df_num.loc[:, 'Cabin'] = df_num['Cabin'].astype('category').cat.codes
# Out:
# <ipython-input-60-30ca473f7135>:1: DeprecationWarning: In a future version, `df.iloc[:, i] = newvals` will attempt to set the values inplace instead of always setting a new array. To retain the old behavior, use either `df[df.columns[i]] = newvals` or, if columns are non-unique, `df.isetitem(i, newvals)`
#   df_num.loc[:, 'Sex'] = df_num['Sex'].astype('category').cat.codes
# <ipython-input-60-30ca473f7135>:2: DeprecationWarning: In a future version, `df.iloc[:, i] = newvals` will attempt to set the values inplace instead of always setting a new array. To retain the old behavior, use either `df[df.columns[i]] = newvals` or, if columns are non-unique, `df.isetitem(i, newvals)`
#   df_num.loc[:, 'Embarked'] = df_num['Embarked'].astype('category').cat.codes
# ...

# %%
x = df_num[['Pclass', 'Sex', 'Age', 'SibSp', 'Parch', 'Fare', 'Cabin', 'Embarked']]
y = df.Survived.values
plt.barh([y[0] for y in f_i], [y[1] for y in f_i])
# Out:
# <BarContainer object of 8 artists>
